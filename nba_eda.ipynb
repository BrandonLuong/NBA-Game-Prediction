# %%
import pandas as pd
import matplotlib
import seaborn as sns

# %%
df = pd.read_csv('cleaned_games_stats.csv')

# %%
df.head()
# Out:
#          Date         Game Home Team  Home MIN  Home PTS  Home FGM  Home FGA  \
# 0  04/10/2022  MIN vs. CHI       MIN       240       120        46        91
# 1  04/10/2022  PHI vs. DET       PHI       240       118        46        88
# 2  04/10/2022  MEM vs. BOS       MEM       240       110        39       102
# 3  04/10/2022  DEN vs. LAL       DEN       265       141        49       100
# 4  04/10/2022  ORL vs. MIA       ORL       240       125        45        91
#
#    Home FG%  Home 3PM  Home 3PA  ...  Away FTA  Away FT%  Away OREB  \
# 0      50.5        11        31  ...        33      78.8         16
# 1      52.3         5        25  ...        29      65.5         15
# 2      38.2        15        47  ...        13     100.0         14
# 3      49.0        15        47  ...        47      89.4         13
# 4      49.5        23        58  ...        16      75.0         10
#
#    Away DREB  Away REB  Away AST  Away STL  Away BLK  Away TOV  Home Wins
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Game', 'Home Team', 'Home MIN', 'Home PTS', 'Home FGM',
#        'Home FGA', 'Home FG%', 'Home 3PM', 'Home 3PA', 'Home 3P%', 'Home FTM',
#        'Home FTA', 'Home FT%', 'Home OREB', 'Home DREB', 'Home REB',
#        'Home AST', 'Home STL', 'Home BLK', 'Home TOV', 'Away Team',
#        'Away Game Date', 'Away PTS', 'Away FGM', 'Away FGA', 'Away FG%',
#        'Away 3PM', 'Away 3PA', 'Away 3P%', 'Away FTM', 'Away FTA', 'Away FT%',
#        'Away OREB', 'Away DREB', 'Away REB', 'Away AST', 'Away STL',
#        'Away BLK', 'Away TOV', 'Home Wins'],
#       dtype='object')

# %%
df.shape
# Out:
# (3369, 41)

# %%
df.describe()
# Out:
#           Home MIN     Home PTS     Home FGM     Home FGA     Home FG%  \
# count  3369.000000  3369.000000  3369.000000  3369.000000  3369.000000
# mean    241.513802   112.260908    41.135945    88.340160    46.660790
# std       6.640801    12.499711     5.215707     6.894656     5.526316
# min     240.000000    73.000000    21.000000    64.000000    26.900000
# 25%     240.000000   104.000000    38.000000    84.000000    42.900000
# 50%     240.000000   112.000000    41.000000    88.000000    46.700000
# 75%     240.000000   121.000000    45.000000    93.000000    50.600000
# max     315.000000   158.000000    63.000000   115.000000    65.400000
#
#           Home 3PM     Home 3PA     Home 3P%     Home FTM     Home FTA  ...  \
# count  3369.000000  3369.000000  3369.000000  3369.000000  3369.000000  ...
# mean     12.559216    34.733452    36.116889    17.429801    22.479668  ...
# std       3.861868     6.911999     8.417314     6.024092     7.245583  ...
# ...

# %%
df['Home PTS'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Away PTS'].hist()
# Out:
# <AxesSubplot:>
